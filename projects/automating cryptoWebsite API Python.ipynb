# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#          id                 name symbol                                slug  \
# 0         1              Bitcoin    BTC                             bitcoin
# 1      1027             Ethereum    ETH                            ethereum
# 2       825          Tether USDt   USDT                              tether
# 3      1839                  BNB    BNB                                 bnb
# 4      3408                 USDC   USDC                            usd-coin
# ...     ...                  ...    ...                                 ...
# 4995  36655                 UZDT   UZDT  ukrainian-sanctioned-digital-token
# 4996  35832  O Intelligence Coin     OI                 o-intelligence-coin
# 4997  33304            WeatherXM    WXM                           weatherxm
# 4998  25987   Water Rabbit Token    WAR                  water-rabbit-token
# 4999  16148          FreeRossDAO   FREE                         freerossdao
#
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)


    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df

    if not os.path.isfile(r'C:\temp\API.csv'):
        df.to_csv(r'C:\temp\API.csv', header=True)
    else:
        df.to_csv(r'C:\temp\API.csv', mode='a', header=False)

# %%
file_path = r"C:\temp\API.csv"
df.to_csv(file_path, index=False, header=True)
print("✅ File saved at:", file_path)
# Out:
# ✅ File saved at: C:\temp\API.csv

# %%
import os 
from time import time
from time import sleep

for i in range(333):

    print('API Runner completed')
    sleep(4) 
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 8
#       4
#       5 for i in range(333):
#       6
#       7     print('API Runner completed')
# ----> 8     sleep(4) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r"C:\temp\API.csv", sep=",")
print(df72.head())
# Out:
#      id         name symbol      slug  infinite_supply  circulating_supply  \
# 0     1      Bitcoin    BTC   bitcoin            False        2.006970e+07
# 1  1027     Ethereum    ETH  ethereum             True        1.206820e+08
# 2   825  Tether USDt   USDT    tether             True        1.831789e+11
# 3  1839          BNB    BNB       bnb            False        1.331640e+08
# 4  3408         USDC   USDC  usd-coin            False        7.206704e+10
#
#    total_supply    max_supply                date_added  num_market_pairs  \
# 0  2.006970e+07  2.100000e+07  2010-07-13T00:00:00.000Z             12695
# 1  1.206820e+08           NaN  2015-08-07T00:00:00.000Z             12473
# 2  1.883435e+11           NaN  2015-02-25T00:00:00.000Z            194298
# 3  1.331640e+08  1.331640e+08  2017-07-25T00:00:00.000Z              3344
# 4  7.206704e+10           NaN  2018-10-08T00:00:00.000Z             43065
#
#    cmc_rank              last_updated  tvl_ratio  platform  \
# ...

# %%
df.to_csv(r"C:\temp\API.csv", index=False, header=True, sep=",")

df72 = pd.read_csv(r"C:\temp\API.csv", sep=",")
print(df72.head())
# Out:
#      id         name symbol      slug  infinite_supply  circulating_supply  \
# 0     1      Bitcoin    BTC   bitcoin            False        2.006970e+07
# 1  1027     Ethereum    ETH  ethereum             True        1.206820e+08
# 2   825  Tether USDt   USDT    tether             True        1.831789e+11
# 3  1839          BNB    BNB       bnb            False        1.331640e+08
# 4  3408         USDC   USDC  usd-coin            False        7.206704e+10
#
#    total_supply    max_supply                date_added  num_market_pairs  \
# 0  2.006970e+07  2.100000e+07  2010-07-13T00:00:00.000Z             12695
# 1  1.206820e+08           NaN  2015-08-07T00:00:00.000Z             12473
# 2  1.883435e+11           NaN  2015-02-25T00:00:00.000Z            194298
# 3  1.331640e+08  1.331640e+08  2017-07-25T00:00:00.000Z              3344
# 4  7.206704e+10           NaN  2018-10-08T00:00:00.000Z             43065
#
#    cmc_rank              last_updated  tvl_ratio  platform  \
# ...

# %%
df
# Out:
#          id                 name symbol                                slug  \
# 0         1              Bitcoin    BTC                             bitcoin
# 1      1027             Ethereum    ETH                            ethereum
# 2       825          Tether USDt   USDT                              tether
# 3      1839                  BNB    BNB                                 bnb
# 4      3408                 USDC   USDC                            usd-coin
# ...     ...                  ...    ...                                 ...
# 4995  36655                 UZDT   UZDT  ukrainian-sanctioned-digital-token
# 4996  35832  O Intelligence Coin     OI                 o-intelligence-coin
# 4997  33304            WeatherXM    WXM                           weatherxm
# 4998  25987   Water Rabbit Token    WAR                  water-rabbit-token
# 4999  16148          FreeRossDAO   FREE                         freerossdao
#
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#          id                 name symbol                                slug  \
# 0         1              Bitcoin    BTC                             bitcoin
# 1      1027             Ethereum    ETH                            ethereum
# 2       825          Tether USDt   USDT                              tether
# 3      1839                  BNB    BNB                                 bnb
# 4      3408                 USDC   USDC                            usd-coin
# ...     ...                  ...    ...                                 ...
# 4995  36655                 UZDT   UZDT  ukrainian-sanctioned-digital-token
# 4996  35832  O Intelligence Coin     OI                 o-intelligence-coin
# 4997  33304            WeatherXM    WXM                           weatherxm
# 4998  25987   Water Rabbit Token    WAR                  water-rabbit-token
# 4999  16148          FreeRossDAO   FREE                         freerossdao
#
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#                      quote.USD.percent_change_1h  \
# name
# Bitcoin                                  0.17800
# Ethereum                                 0.21088
# Tether USDt                             -0.01714
# BNB                                      0.27059
# USDC                                    -0.00191
# ...                                          ...
# UZDT                                     0.07389
# O Intelligence Coin                     -2.69719
# WeatherXM                                2.00448
# Water Rabbit Token                       0.25845
# FreeRossDAO                             -0.48240
#
#                      quote.USD.percent_change_24h  \
# name
# Bitcoin                                  -0.42028
# Ethereum                                 -0.51739
# Tether USDt                              -0.00704
# BNB                                      -0.40965
# USDC                                      0.01144
# ...                                           ...
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     0.17800
#              quote.USD.percent_change_24h   -0.42028
#              quote.USD.percent_change_7d    -2.23520
#              quote.USD.percent_change_30d   -2.33104
#              quote.USD.percent_change_60d   -0.87208
#                                               ...
# FreeRossDAO  quote.USD.percent_change_24h   -0.60163
#              quote.USD.percent_change_7d    -0.26498
#              quote.USD.percent_change_30d   -0.73478
#              quote.USD.percent_change_60d    0.70687
#              quote.USD.percent_change_90d    0.46371
# Length: 29868, dtype: float64

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                            values
# name
# Bitcoin     quote.USD.percent_change_1h   0.17800
#             quote.USD.percent_change_24h -0.42028
#             quote.USD.percent_change_7d  -2.23520
#             quote.USD.percent_change_30d -2.33104
#             quote.USD.percent_change_60d -0.87208
# ...                                           ...
# FreeRossDAO quote.USD.percent_change_24h -0.60163
#             quote.USD.percent_change_7d  -0.26498
#             quote.USD.percent_change_30d -0.73478
#             quote.USD.percent_change_60d  0.70687
#             quote.USD.percent_change_90d  0.46371
#
# [29868 rows x 1 columns]

# %%
df5.count()
# Out:
# values    29868
# dtype: int64

# %%
index = pd.Index(range(len(df5)))
df6 = df5.reset_index()
df6
# Out:
#               name                       level_1   values
# 0          Bitcoin   quote.USD.percent_change_1h  0.17800
# 1          Bitcoin  quote.USD.percent_change_24h -0.42028
# 2          Bitcoin   quote.USD.percent_change_7d -2.23520
# 3          Bitcoin  quote.USD.percent_change_30d -2.33104
# 4          Bitcoin  quote.USD.percent_change_60d -0.87208
# ...            ...                           ...      ...
# 29863  FreeRossDAO  quote.USD.percent_change_24h -0.60163
# 29864  FreeRossDAO   quote.USD.percent_change_7d -0.26498
# 29865  FreeRossDAO  quote.USD.percent_change_30d -0.73478
# 29866  FreeRossDAO  quote.USD.percent_change_60d  0.70687
# 29867  FreeRossDAO  quote.USD.percent_change_90d  0.46371
#
# [29868 rows x 3 columns]

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#               name                percent_change   values
# 0          Bitcoin   quote.USD.percent_change_1h  0.17800
# 1          Bitcoin  quote.USD.percent_change_24h -0.42028
# 2          Bitcoin   quote.USD.percent_change_7d -2.23520
# 3          Bitcoin  quote.USD.percent_change_30d -2.33104
# 4          Bitcoin  quote.USD.percent_change_60d -0.87208
# ...            ...                           ...      ...
# 29863  FreeRossDAO  quote.USD.percent_change_24h -0.60163
# 29864  FreeRossDAO   quote.USD.percent_change_7d -0.26498
# 29865  FreeRossDAO  quote.USD.percent_change_30d -0.73478
# 29866  FreeRossDAO  quote.USD.percent_change_60d  0.70687
# 29867  FreeRossDAO  quote.USD.percent_change_90d  0.46371
#
# [29868 rows x 3 columns]

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
# Out:
#               name               percent_change   values
# 0          Bitcoin  quote.USD.percent_change_1h  0.17800
# 1          Bitcoin                          24h -0.42028
# 2          Bitcoin                           7d -2.23520
# 3          Bitcoin                          30d -2.33104
# 4          Bitcoin                          60d -0.87208
# ...            ...                          ...      ...
# 29863  FreeRossDAO                          24h -0.60163
# 29864  FreeRossDAO                           7d -0.26498
# 29865  FreeRossDAO                          30d -0.73478
# 29866  FreeRossDAO                          60d  0.70687
# 29867  FreeRossDAO                          90d  0.46371
#
# [29868 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3040, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3028     p._point_kwargs_backcompat(
#    3029         kwargs.pop("scale", deprecated),
#    3030         kwargs.pop("join", deprecated),
#    3031         kwargs
#    3032     )
#    3033     err_kws, capsize = p._err_kws_backcompat(
#    3034         normalize_kwargs(kwargs.pop("err_kws", {}), mpl.lines.Line2D),
# ...

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      63139.73002 2026-08-13 18:57:32.475028

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
